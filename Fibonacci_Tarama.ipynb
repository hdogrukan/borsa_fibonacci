# %%
# !pip install stockstats
# !pip install investpy

# %%
import time
import math
import pandas_datareader as web
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
import investpy
from stockstats import StockDataFrame
import datetime

# %%
hisse = [ 'ADEL', 'ADESE', 'AEFES', 'AFYON', 'AGYO', 'AKBNK', 'AKCNS', 'AKENR', 'AKFGY', 'AKGRT', 'AKMGY', 'AKSA', 'AKSEN', 'AKSUE', 'ALARK', 'ALBRK', 'ALCAR', 'ALCTL', 'ALGYO', 'ALKA', 'ALKIM', 'ALYAG', 
         'ANELE', 'ANHYT', 'ANSGR', 'ARCLK', 'ARENA', 'ARMDA', 'ARSAN', 'ASELS', 'ASUZU', 'ATAGY', 'ATEKS', 'ATLAS', 'AVGYO', 'AVOD', 'AVTUR', 'AYCES', 'AYEN', 'AYGAZ', 'BAGFS', 'BAKAB', 'BANVT', 
         'BFREN', 'BIMAS', 'RALYH', 'BIZIM', 'BJKAS', 'BLCYT',  'BOSSA', 'BRKO', 'BRKSN', 'BRMEN', 'YYAPI', 'BRSAN', 'BRYAT', 'BSOKE', 'BTCIM', 'BUCIM', 'BURCE', 'BURVA', 'CRFSA', 'CCOLA', 'CELHA', 
         'CEMAS', 'CEMTS', 'CIMSA', 'CLEBI', 'CMBTN', 'CMENT', 'DOKTA', 'COSMO', 'CRDFA', 'DAGI', 'DARDL',  'DERIM', 'DESA', 'DESPC', 'DEVA', 'DGATE', 'DGGYO', 'DITAS', 'DMSAS', 'DZGYO', 'DOAS', 'DOBUR', 
         'DOCO', 'DOGUB', 'DOHOL', 'DURDO', 'DYOBY', 'MTRYO', 'ECILC', 'ECZYT', 'EDIP',  'EGEEN', 'EGGUB', 'EGPRO', 'EGSER', 'EKGYO', 'EKIZ', 'EUYO', 'EMKEL', 'EMNIS', 'ENKAI', 'EPLAS', 
         'ERBOS', 'EREGL', 'ERSU', 'ESCOM', 'ETYAT', 'EUKYO', 'EUHOL', 'FENER', 'QNBFL', 'QNBFB', 'FMIZP', 'UFUK', 'FRIGO', 'FROTO', 'GARAN', 'GARFA', 'GYHOL', 'GEDIK', 'GENTS', 'GEREL', 'GLBMD', 'GLRYH', 
         'GLYHO', 'GOLTS', 'GOODY', 'GOZDE', 'GRNYO', 'GSDDE', 'GSDHO', 'GSRAY', 'GUBRF', 'GUSGR', 'HALKB', 'HATEK', 'HEKTS', 'HURGZ', 'IDGYO', 'IHEVA', 'IHGZT', 'IHLAS', 'IHLGM', 'IHYAY', 'INDES', 'INFO', 
         'INTEM', 'IPEKE', 'ISATR', 'ISBTR', 'ISCTR', 'ISFIN', 'ISGSY', 'ISGYO', 'ISMEN', 'ISYAT', 'ITTFH', 'IZMDC', 'KAPLM', 'KAREL', 'KARSN', 'KARTN', 'KATMR', 'KCHOL', 'KENT', 'KERVT', 'DGKLB', 'KLGYO', 
         'KLMSN', 'KLNMA', 'KNFRT', 'KONYA', 'KORDS', 'KOZAA', 'KOZAL', 'KRDMA', 'KRDMB', 'KRDMD', 'KRONT', 'KRSTL', 'KRTEK', 'KUTPO', 'LINK', 'LKMNH', 'LOGO', 'LUKSK', 'MAALT', 'MAKTK', 'MARTI', 
          'MEPET', 'MERKO', 'METRO', 'METUR', 'MGROS', 'MIPAZ', 'MNDRS', 'MRDIN', 'MRGYO', 'MRSHL', 'IEYHO', 'MZHLD', 'NETAS', 'NTHOL', 'NUGYO', 'NUHCM', 'OTKAR', 'OYAYO', 'OZBAL', 'OZGYO', 'PARSN', 
         'PEGYO', 'PENGD', 'PETKM', 'PETUN', 'PINSU', 'PKART', 'PKENT', 'PNSUT', 'PRKAB', 'PRKME', 'RAYSG', 'RHEAG', 'RYGYO', 'RYSAS', 'SAHOL', 'SAMAT', 'SANKO', 'SARKY', 'SASA', 'SEKFK', 'SELEC', 'SELGD', 
         'SERVE', 'ISKUR', 'SILVR', 'SISE', 'SKBNK', 'SKTAS', 'SNGYO', 'SNPAM', 'SONME', 'TATGD', 'TAVHL', 'TBORG', 'TCELL', 'ICBCT', 'TEKTU', 'THYAO', 'TIRE', 'TKFEN', 'TOASO', 'TRCAS', 'TRGYO', 
          'TSGYO', 'TSKB', 'TSPOR', 'TTKOM', 'TTRAK', 'TUKAS', 'TUPRS', 'ULKER',  'USAK', 'UTPYA', 'VAKBN', 'VAKFN', 'VAKKO', 'VANGD', 'VESBE', 'VESTL', 'VKGYO', 'VKING', 'YAPRK', 'YATAS', 'AGHOL', 
         'YGYO', 'YKBNK', 'YKGYO', 'YUNSA', 'ZOREN', 'BRISA', 'MARKA', 'ATSYH', 'BALAT', 'BEYAZ', 'DAGHL', 'DENGE', 'HUBVC', 'IDEAS', 'MMCAS', 'NIBAS', 'ORGE', 'OSMEN', 'OSTIM', 'OYLUM', 'OZKGY', 
         'POLHO', 'SANFM', 'SODSN', 'TKNSA', 'ULAS', 'VKFYO', 'YBTAS', 'YESIL', 'AKGUV', 'AYES', 'BASCM', 'AVHOL', 'DIRIT', 'ETILR', 'FLAP', 'HLGYO', 'JANTS', 'KERVN', 'BERA', 'KRSAN', 'KUYAS', 'MEGAP', 'MERIT', 'PGSUS',
         'PRZMA', 'TGSAS', 'TKURU', 'TMSN', 'UZERB', 'ROYAL', 'ODAS', 'PAGYO', 'TURGG', 'ACSEL', 'AKSGY', 'TACTR', 'SEKUR', 'IZTAR', 'VERUS', 'ORMA', 'YAYLA', 'SANEL', 'TMPOL', 'RODRG', 'GEDZA', 'KRGYO', 'LIDFA', 'OLMIP', 
         'RTALB', 'SRVGY', 'TUCLK', 'YGGYO', 'BMELK', 'AVISA', 'PSDTC', 'ULUUN', 'ULUSE', 'HDFGS', 'OZRDN', 'SNKRN', 'POLTK', 'SAYAS', 'BNTAS', 'SEYKM', 'VERTU', 'CUSAN', 'ISDMR', 'ISBIR', 'IZFAS', 'KSTUR', 'UMPAS', 
         'YONGA', 'MSGYO', 'FONET', 'MAVI', 'SAFKR', 'TLMAN', 'ENJSA', 'MPARK', 'PEKGY', 'TDGYO', 'SOKM', 'KFEIN', 'FORMT', 'SUMAS', 'SMART', 'CEOEM', 'DERAS', 'NATEN']

# %%
def find_alarm_1():
    #returns = df['Close'].pct_change().tail(1)
    x=df['High'].max()
    y=df['Low'].min()
    
    fibonacci_0 = df['High'].max()                  # % 0
    fibonacci_1 = fibonacci_0 - (x-y)*0.2360    # %23,60
    fibonacci_2 = fibonacci_0 - (x-y)*0.3820    # %38,20
    fibonacci_3 = fibonacci_0 - (x-y)*0.5       # %50
    fibonacci_4 = fibonacci_0 - (x-y)*0.6180    # %61,80
    fibonacci_5 = fibonacci_0 - (x-y)*0.7860    # %78,60
    fibonacci_6 = df['Low'].min()                  # %100
    # Koşul 1 Son kapanış %61,80 'demi ? Son kapanış %50'den küçük ve 61,80'den büyükmü (düşüş trendi)
    # fibonaci_3 > df['Low][-1] Bu şart düşüş trendi için 
    # df['Low][-1] < (fibonaci_3 + ((fibonaci_3 -fibonaci_4)*0,5 ))
    
    #print("Fibonacci High Date: ",df['High'].idxmax() )
    #print("Fibonacci Low Date: ",df['Low'].idxmin() )
    #print(fibonacci_1)
    str
    z=df['Low'][-1]
    #print(z)
    high_date=df['High'].idxmax()
    low_date =df['Low'].idxmin ()

    print("High_date: ", high_date)
    print("Low_date: ", low_date)
    day = high_date > low_date
    print(day)
    level= fibonacci_3 - ((fibonacci_3-fibonacci_4)*0.8)
    
    level2= fibonacci_5 + ((fibonacci_4-fibonacci_5)*0.8)
    print(level)
    print(level2)
    print(z)
    print("High: ",fibonacci_0)
    #if ((fibonacci_3 > z) & (z<level)) & ((day==True) & (z>=fibonacci_4)):

    if ((fibonacci_3 > z) & ((z>level2 )&(z<level))) & (day==True) :

        print("Al Sinyali bulundu... :",h)
        # print(h)
        with open("fibonacci.txt","a", encoding="utf-8") as file2:
            
            #file2.write("Hisse: \n"+h+"\n High: "+str(fibonacci_0)+"\n Low: "+ str(fibonacci_6)+" Fibonacci High Date: " + str(high_date)  + " " + " Fibonacci Low Date: " + str(low_date) + " Fibonacci_3: "+str(fibonacci_3)+ " Fibonacci_4: "+ str(fibonacci_4) +" Fibonacci_5: " +str(fibonacci_5) )
            
            file2.write("Hisse: "+h+ " Fibonacci Başlangıç: "+ str(start_day) )
            file2.write("\nGüncel Fiyat: "+ str(df['Close'][-1]))
            file2.write("\nHigh Price: "+str(fibonacci_0)+ " High Date: "+ str(high_date))
            file2.write("\nLow Price: "+str(fibonacci_6)+" Low Date: "+ str(low_date))
            file2.write("\nFibonacci %61,80: "+str(fibonacci_4))
            file2.write("\nFibonacci %50: "+str(fibonacci_3))
            file2.write("\n")
            file2.write("\n")
            #"High:" +"str(fibonacci_0)"\n Low: "+ str(fibonacci_6)+" Fibonacci High Date: " + str(high_date)  + " " + " Fibonacci Low Date: " + str(low_date) + " Fibonacci_3: "+str(fibonacci_3)+ " Fibonacci_4: "+ str(fibonacci_4) +" Fibonacci_5: " +str(fibonacci_5) )
            
            file2.write("\n")

        with open("Hisseler.txt","a", encoding="utf-8") as file2:
            
            #file2.write("Hisse: \n"+h+"\n High: "+str(fibonacci_0)+"\n Low: "+ str(fibonacci_6)+" Fibonacci High Date: " + str(high_date)  + " " + " Fibonacci Low Date: " + str(low_date) + " Fibonacci_3: "+str(fibonacci_3)+ " Fibonacci_4: "+ str(fibonacci_4) +" Fibonacci_5: " +str(fibonacci_5) )
            
            file2.write("#"+h+", " )

# %%
"""today = datetime.date.today()
today = today.strftime("%d/%m/%Y")
df = investpy.get_stock_historical_data(stock="ADEL", country='Turkey', from_date='01/02/2021', to_date=today)"""

# %%
today = datetime.date.today()
start_day = today - pd.Timedelta(days=30)
today = today.strftime("%d/%m/%Y")
start_day = start_day.strftime("%d/%m/%Y")

for h in hisse:
    print(h)
    h=str(h)
    df = investpy.get_stock_historical_data(stock=h, country='Turkey', from_date='01/03/2021', to_date=today)
    #df = web.get_data_yahoo(h, start="2020-01-01", end=today)
    
    #stocks = StockDataFrame.retype(df[["Open", "Close", "High", "Low", "Volume"]])
    find_alarm_1()
    #buy_alarm_2()

# %%
with open("Hisseler.txt","r", encoding="utf-8") as file4:
    mail_content=file4.read()

# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
"""mail_content = '''Hello,
This is a simple mail. There is only text, no attachments are there The mail is sent using Python SMTP library.
Thank You
'''"""
mail_content

#The mail addresses and password
sender_address = 'xxxxxxxxxxx@gmail.com'
sender_pass = 'xxxxxxxxxxxxxx'
receiver_address = 'xxxxxxxxx@gmail.com'
#Setup the MIME
message = MIMEMultipart()
message['From'] = sender_address
message['To'] = receiver_address
message['Subject'] = 'Haftalık Fibonacci Listesi'   #The subject line
#The body and the attachments for the mail
message.attach(MIMEText(mail_content, 'plain'))
#Create SMTP session for sending the mail
session = smtplib.SMTP('smtp.gmail.com', 587) #use gmail with port
session.starttls() #enable security
session.login(sender_address, sender_pass) #login with mail_id and password
text = message.as_string()
session.sendmail(sender_address, receiver_address, text)
session.quit()
print('Mail Sent')
